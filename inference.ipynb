# %%
from autodistill_grounded_sam_2 import GroundedSAM2
from autodistill.detection import CaptionOntology
from autodistill.utils import plot

base_model = GroundedSAM2(
    ontology=CaptionOntology(
        {
            "building": "building",
        }
    )
)

# run inference on a single image
results = base_model.predict("logistics.jpeg")

# %%
import os
from samgeo.text_sam import LangSAM
# Out:
# Installing GroundingDINO...
# Collecting groundingdino-py
# Downloading groundingdino-py-0.4.0.tar.gz (82 kB)
# Preparing metadata (setup.py): started
# Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: torch in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from groundingdino-py) (2.5.1)
# Requirement already satisfied: torchvision in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from groundingdino-py) (0.20.1)
# Collecting transformers (from groundingdino-py)
# Downloading transformers-4.48.1-py3-none-any.whl.metadata (44 kB)
# Collecting addict (from groundingdino-py)
# Downloading addict-2.4.0-py3-none-any.whl.metadata (1.0 kB)
# Collecting yapf (from groundingdino-py)
# Downloading yapf-0.43.0-py3-none-any.whl.metadata (46 kB)
# Requirement already satisfied: timm in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from groundingdino-py) (1.0.14)
# Requirement already satisfied: numpy in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from groundingdino-py) (1.26.4)
# Requirement already satisfied: opencv-python in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from groundingdino-py) (4.10.0.84)
# Collecting supervision==0.6.0 (from groundingdino-py)
# Downloading supervision-0.6.0-py3-none-any.whl.metadata (6.2 kB)
# Requirement already satisfied: pycocotools in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from groundingdino-py) (2.0.8)
# Requirement already satisfied: matplotlib in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from supervision==0.6.0->groundingdino-py) (3.8.2)
# Requirement already satisfied: pyyaml in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from timm->groundingdino-py) (6.0.2)
# Requirement already satisfied: huggingface_hub in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from timm->groundingdino-py) (0.27.1)
# Requirement already satisfied: safetensors in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from timm->groundingdino-py) (0.5.2)
# Requirement already satisfied: filelock in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from torch->groundingdino-py) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from torch->groundingdino-py) (4.12.2)
# Requirement already satisfied: networkx in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from torch->groundingdino-py) (3.4.2)
# Requirement already satisfied: jinja2 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from torch->groundingdino-py) (3.1.5)
# Requirement already satisfied: fsspec in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from torch->groundingdino-py) (2024.12.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from torch->groundingdino-py) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from torch->groundingdino-py) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from torch->groundingdino-py) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from torch->groundingdino-py) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from torch->groundingdino-py) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from torch->groundingdino-py) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from torch->groundingdino-py) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from torch->groundingdino-py) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from torch->groundingdino-py) (12.3.1.170)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from torch->groundingdino-py) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from torch->groundingdino-py) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from torch->groundingdino-py) (12.4.127)
# Requirement already satisfied: triton==3.1.0 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from torch->groundingdino-py) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from torch->groundingdino-py) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from sympy==1.13.1->torch->groundingdino-py) (1.3.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from torchvision->groundingdino-py) (10.4.0)
# Requirement already satisfied: packaging>=20.0 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from transformers->groundingdino-py) (24.2)
# Collecting regex!=2019.12.17 (from transformers->groundingdino-py)
# Downloading regex-2024.11.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (40 kB)
# Requirement already satisfied: requests in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from transformers->groundingdino-py) (2.32.3)
# Collecting tokenizers<0.22,>=0.21 (from transformers->groundingdino-py)
# Downloading tokenizers-0.21.0-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: tqdm>=4.27 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from transformers->groundingdino-py) (4.67.1)
# Requirement already satisfied: platformdirs>=3.5.1 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from yapf->groundingdino-py) (4.3.6)
# Requirement already satisfied: tomli>=2.0.1 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from yapf->groundingdino-py) (2.2.1)
# Requirement already satisfied: contourpy>=1.0.1 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from matplotlib->supervision==0.6.0->groundingdino-py) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from matplotlib->supervision==0.6.0->groundingdino-py) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from matplotlib->supervision==0.6.0->groundingdino-py) (4.55.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from matplotlib->supervision==0.6.0->groundingdino-py) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from matplotlib->supervision==0.6.0->groundingdino-py) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from matplotlib->supervision==0.6.0->groundingdino-py) (2.9.0.post0)
# Requirement already satisfied: MarkupSafe>=2.0 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from jinja2->torch->groundingdino-py) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from requests->transformers->groundingdino-py) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from requests->transformers->groundingdino-py) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from requests->transformers->groundingdino-py) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from requests->transformers->groundingdino-py) (2024.12.14)
# Requirement already satisfied: six>=1.5 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib->supervision==0.6.0->groundingdino-py) (1.17.0)
# Downloading supervision-0.6.0-py3-none-any.whl (31 kB)
# Downloading addict-2.4.0-py3-none-any.whl (3.8 kB)
# Downloading transformers-4.48.1-py3-none-any.whl (9.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 51.3 MB/s eta 0:00:00a 0:00:01
# Downloading yapf-0.43.0-py3-none-any.whl (256 kB)
# Downloading regex-2024.11.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (781 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 781.7/781.7 kB 14.1 MB/s eta 0:00:00
# Downloading tokenizers-0.21.0-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 97.1 MB/s eta 0:00:00
# Building wheels for collected packages: groundingdino-py
# Building wheel for groundingdino-py (setup.py): started
# Building wheel for groundingdino-py (setup.py): finished with status 'done'
# Created wheel for groundingdino-py: filename=groundingdino_py-0.4.0-py2.py3-none-any.whl size=88733 sha256=4be6786a9f8a83ad1e50be6b3b7f5fcce041f65ba76b8f666ba94f2459c904cf
# Stored in directory: /home/zeus/.cache/pip/wheels/72/25/30/97b491abad279d329c62bef1e91bc56bf2fd40b22281068e1d
# Successfully built groundingdino-py
# Installing collected packages: addict, yapf, regex, tokenizers, supervision, transformers, groundingdino-py
# Attempting uninstall: tokenizers
# Found existing installation: tokenizers 0.20.3
# Uninstalling tokenizers-0.20.3:
# Successfully uninstalled tokenizers-0.20.3
# Attempting uninstall: supervision
# Found existing installation: supervision 0.25.1
# Uninstalling supervision-0.25.1:
# Successfully uninstalled supervision-0.25.1
# Successfully installed addict-2.4.0 groundingdino-py-0.4.0 regex-2024.11.6 supervision-0.6.0 tokenizers-0.21.0 transformers-4.48.1 yapf-0.43.0
# Please restart the kernel and run the notebook again.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# inference-gpu 0.35.0 requires supervision<=0.30.0,>=0.25.1, but you have supervision 0.6.0 which is incompatible.
# inference-gpu 0.35.0 requires tokenizers<=0.20.3,>=0.19.0, but you have tokenizers 0.21.0 which is incompatible.

# %%
os.listdir('..//images/data/images/')
# Out:
# ['Akins HS.png',
#  'Akins HS.tif',
#  'Allison Elem.png',
#  'Allison Elem.tif',
#  'Alternative Learning Center.png',
#  'Alternative Learning Center.tif',
#  'Anderson HS.png',
#  'Anderson HS.tif',
#  'Andrews Elem.png',
#  'Andrews Elem.tif',
#  'Austin HS.png',
#  'Austin HS.tif',
#  'Austin ISD Prek Partnership (Pkp).png',
#  'Austin ISD Prek Partnership (Pkp).tif',
#  'Austin St Hospital.png',
#  'Austin St Hospital.tif',
#  'Bailey MS.png',
#  'Bailey MS.tif',
#  'Baldwin Elem.png',
#  'Baldwin Elem.tif',
#  'Baranoff Elem.png',
#  'Baranoff Elem.tif',
#  'Barrington Elem.png',
#  'Barrington Elem.tif',
#  'Barton Hills Elem.png',
#  'Barton Hills Elem.tif',
#  'Bear Creek Elem.png',
#  'Bear Creek Elem.tif',
#  'Becker Elem.png',
#  'Becker Elem.tif',
#  'Bedichek MS.png',
#  'Bedichek MS.tif',
#  'Blackshear Elem.png',
#  'Blackshear Elem.tif',
#  'Blanton Elem.png',
#  'Blanton Elem.tif',
#  'Blazier Elem.png',
#  'Blazier Elem.tif',
#  'Boone Elem.png',
#  'Boone Elem.tif',
#  'Bowie HS.png',
#  'Bowie HS.tif',
#  'Brentwood Elem.png',
#  'Brentwood Elem.tif',
#  'Brown Elem.png',
#  'Brown Elem.tif',
#  'Bryker Woods Elem.png',
#  'Bryker Woods Elem.tif',
#  'Burnet MS.tif',
#  'Campbell Elem.tif',
#  'Casey Elem.tif',
#  'Casis Elem.tif',
#  'Clayton Elem.tif',
#  'Cook Elem.tif',
#  'Covington MS.tif',
#  'Cowan Elem.png',
#  'Cowan Elem.tif',
#  'Crockett ECHS.tif',
#  'Cunningham Elem.tif',
#  'Davis Elem.tif',
#  'Dawson Elem.tif',
#  'Dobie MS.tif',
#  'Doss Elem.tif',
#  'Eastside Early College HS.tif',
#  'Galindo Elem.tif',
#  'Garcia YMLA.tif',
#  'Garza Independence HS.tif',
#  'Gorzycki MS.tif',
#  'Govalle Elem.tif',
#  'Graduation Prep Academy Navarro.tif',
#  'Graduation Preparatory Academy.tif',
#  'Graham Elem.tif',
#  'Greenleaf NCC.tif',
#  'Guerrero Thompson.tif',
#  'Gullett Elem.tif',
#  'Harris Elem.tif',
#  'Hart Elem.tif']
